# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## importing dataset

# %%
dataset = pd.read_csv("sample_log_dataset.csv")
dataset
# Out:
#                Timestamp                Source SourceClass    Destination  \
# 0    2024-07-20T12:45:31            10.0.0.100   malicious     10.0.0.101
# 1    2024-07-20T12:45:31  217.151.51.228:54125   malicious     10.0.0.101
# 2    2024-07-20T12:45:31            10.0.0.100   malicious    10.10.10.20
# 3    2024-07-20T12:45:31            10.0.0.100   malicious    192.168.2.6
# 4    2024-07-20T12:45:31           172.16.0.10   malicious  192.38.89.174
# ..                   ...                   ...         ...            ...
# 495  2024-07-20T12:45:31           10.10.10.10   malicious  164.237.23.35
# 496  2024-07-20T12:45:31          192.168.10.5   malicious       10.0.0.3
# 497  2024-07-20T12:45:31           192.168.2.5   malicious       10.1.1.2
# 498  2024-07-20T12:45:31           10.10.10.10   malicious    192.168.0.2
# 499  2024-07-20T12:45:31          172.16.1.100   malicious    192.168.0.3
#
#     DestinationClass       User          Device                     EventType  \
# 0               safe  anonymous       DeviceXYZ           credit-limit-change
# 1               safe      admin       ServerABC    money-laundering-suspicion
# 2               safe      admin       ServerABC                  auth-lockout
# 3               safe    user123  Workstation123                   payee-added
# 4          malicious      guest       ServerABC                  auth-lockout
# ..               ...        ...             ...                           ...
# 495        malicious      guest       ServerABC                   payee-added
# 496             safe      admin       DeviceXYZ             transaction-large
# 497             safe      admin       ServerABC  transaction-unusual-location
# 498             safe      guest       DeviceXYZ          identity-theft-alert
# 499             safe      admin  Workstation123     insider-trading-suspicion
#
#                                            Description Severity  MLRiskScore
# 0    Credit limit change requested for account 247....      low         0.50
# 1    Potential money laundering activity detected f...      low         0.63
# 2    User 'admin' locked out after multiple failed ...   medium         0.57
# 3             New payee added to account 145.32.221.89   medium         0.47
# 4    User 'guest' locked out after multiple failed ...   medium         0.83
# ..                                                 ...      ...          ...
# 495           New payee added to account 75.148.42.172     high         0.73
# 496  Large transaction detected: $195774 for accoun...   medium         0.53
# 497  Transaction from unusual location for account ...      low         0.60
# 498  Potential identity theft detected for account ...   medium         0.63
# 499  Potential insider trading flagged for account ...     high         0.60
#
# [500 rows x 11 columns]

# %% [markdown]
# ## dropping redundant columns

# %%
dataset.drop(columns=['Source', 'Destination', 'Timestamp', 'Description'], inplace=True)
# dataset

# %% [markdown]
# ## label encoding Source and Destination IPs (safe and malicious)

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
columns = ['SourceClass', 'DestinationClass']

dataset[columns] = dataset[columns].apply(le.fit_transform)
dataset
# Out:
#      SourceClass  DestinationClass       User          Device  \
# 0              0                 1  anonymous       DeviceXYZ
# 1              0                 1      admin       ServerABC
# 2              0                 1      admin       ServerABC
# 3              0                 1    user123  Workstation123
# 4              0                 0      guest       ServerABC
# ..           ...               ...        ...             ...
# 495            0                 0      guest       ServerABC
# 496            0                 1      admin       DeviceXYZ
# 497            0                 1      admin       ServerABC
# 498            0                 1      guest       DeviceXYZ
# 499            0                 1      admin  Workstation123
#
#                         EventType Severity  MLRiskScore
# 0             credit-limit-change      low         0.50
# 1      money-laundering-suspicion      low         0.63
# 2                    auth-lockout   medium         0.57
# 3                     payee-added   medium         0.47
# 4                    auth-lockout   medium         0.83
# ..                            ...      ...          ...
# 495                   payee-added     high         0.73
# 496             transaction-large   medium         0.53
# 497  transaction-unusual-location      low         0.60
# 498          identity-theft-alert   medium         0.63
# 499     insider-trading-suspicion     high         0.60
#
# [500 rows x 7 columns]

# %%
## Severity Column
event_severity_threat = {"informational": 0.1, "warning": 0.7, "error": 0.4, "critical": 0.9}
dataset['Severity'] = dataset['Severity'].replace(event_severity_threat).astype(float)

## EventType Column
event_type_threat = {
    "auth-failed": 0.8,
    "auth-success": 0.1,
    "auth-lockout": 0.9,
    "network-connected": 0.2,
    "network-disconnected": 0.2,
    "firewall-change": 0.7,
    "dns-queries": 0.3,
    "malware-detection": 0.9,
    "system-shutdown": 0.8,
    "system-restart": 0.7,
    "system-failure": 0.9,
    "application-errors": 0.6,
    "application-usage": 0.2,
    "api-called": 0.4,
    "file-access": 0.5,
    "permission-changes": 0.3,
    "software-update": 0.6
}
dataset['EventType'] = dataset['EventType'].replace(event_type_threat).astype(float)

## Device Column
devices = {"Workstation123": 1, "DeviceXYZ": 2, "ServerABC": 3}
dataset['Device'] = dataset['Device'].replace(devices)

## User Column
users = {"user123": 1, "guest": 2, "admin": 3, "anonymous":4}
dataset['User'] = dataset['User'].replace(users)

dataset['Access'] = np.random.randint(2, size=500)

dataset
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 3
#       1 ## Severity Column
#       2 event_severity_threat = {"informational": 0.1, "warning": 0.7, "error": 0.4, "critical": 0.9}
# ----> 3 dataset['Severity'] = dataset['Severity'].replace(event_severity_threat).astype(float)
#       5 ## EventType Column
#       6 event_type_threat = {
#       7     "auth-failed": 0.8,
#       8     "auth-success": 0.1,
#    (...)     23     "software-update": 0.6
#      24 }
#
# File ~/Documents/BLINC/FABRIC-master/venv/lib/python3.13/site-packages/pandas/core/generic.py:6662, in NDFrame.astype(self, dtype, copy, errors)
#    6656     results = [
#    6657         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6658     ]
#    6660 else:
#    6661     # else, only a single dtype is given
# -> 6662     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6663     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6664     return res.__finalize__(self, method="astype")
#
# File ~/Documents/BLINC/FABRIC-master/venv/lib/python3.13/site-packages/pandas/core/internals/managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# --> 430 return self.apply(
#     431     "astype",
#     432     dtype=dtype,
#     433     copy=copy,
#     434     errors=errors,
#     435     using_cow=using_copy_on_write(),
#     436 )
#
# File ~/Documents/BLINC/FABRIC-master/venv/lib/python3.13/site-packages/pandas/core/internals/managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~/Documents/BLINC/FABRIC-master/venv/lib/python3.13/site-packages/pandas/core/internals/blocks.py:784, in Block.astype(self, dtype, copy, errors, using_cow, squeeze)
#     781         raise ValueError("Can not squeeze with more than one column.")
#     782     values = values[0, :]  # type: ignore[call-overload]
# --> 784 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     786 new_values = maybe_coerce_values(new_values)
#     788 refs = None
#
# File ~/Documents/BLINC/FABRIC-master/venv/lib/python3.13/site-packages/pandas/core/dtypes/astype.py:237, in astype_array_safe(values, dtype, copy, errors)
#     234     dtype = dtype.numpy_dtype
#     236 try:
# --> 237     new_values = astype_array(values, dtype, copy=copy)
#     238 except (ValueError, TypeError):
#     239     # e.g. _astype_nansafe can fail on object-dtype of strings
#     240     #  trying to convert to float
#     241     if errors == "ignore":
#
# File ~/Documents/BLINC/FABRIC-master/venv/lib/python3.13/site-packages/pandas/core/dtypes/astype.py:182, in astype_array(values, dtype, copy)
#     179     values = values.astype(dtype, copy=copy)
#     181 else:
# --> 182     values = _astype_nansafe(values, dtype, copy=copy)
#     184 # in pandas we don't store numpy str dtypes, so convert to object
#     185 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~/Documents/BLINC/FABRIC-master/venv/lib/python3.13/site-packages/pandas/core/dtypes/astype.py:133, in _astype_nansafe(arr, dtype, copy, skipna)
#     129     raise ValueError(msg)
#     131 if copy or arr.dtype == object or dtype == object:
#     132     # Explicit copy, or required since NumPy can't view from / to object.
# --> 133     return arr.astype(dtype, copy=True)
#     135 return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: 'low'

# %% [markdown]
# ## splitting into X and Y

# %%
X = dataset.iloc[:, :-2]
y = dataset.iloc[:,-2]
y2 = dataset.iloc[:,-1]

y2
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 495    1
# 496    0
# 497    1
# 498    0
# 499    0
# Name: Access, Length: 500, dtype: int64

# %% [markdown]
# ## importing catboost regressor

# %%
from catboost import CatBoostRegressor
cat_model = CatBoostRegressor(verbose = False)

# %% [markdown]
# ## importing lightgbm regressor

# %%
import lightgbm as lgb 

lgb_model = lgb.LGBMRegressor()

# %% [markdown]
# ## importing xgboost regressor

# %%
from xgboost import XGBRegressor

xgb_model = XGBRegressor()

# %% [markdown]
# ## stacking these models together

# %%
from sklearn.neural_network import MLPRegressor
from sklearn.ensemble import StackingRegressor

base_regressors = [
    ('lightgbm', lgb_model),
    ('catboost', cat_model),
    ('xgboost', xgb_model)
]

meta_regressor = MLPRegressor(hidden_layer_sizes=(400, 200, 100, 50), activation='relu', solver='adam', random_state=42)


model = StackingRegressor(estimators=base_regressors, final_estimator=meta_regressor)
model
# Out:
# StackingRegressor(estimators=[('lightgbm', LGBMRegressor()),
#                               ('catboost',
#                                <catboost.core.CatBoostRegressor object at 0x10b854050>),
#                               ('xgboost',
#                                XGBRegressor(base_score=None, booster=None,
#                                             callbacks=None,
#                                             colsample_bylevel=None,
#                                             colsample_bynode=None,
#                                             colsample_bytree=None, device=None,
#                                             early_stopping_rounds=None,
#                                             enable_categorical=False,
#                                             eval_metric=None,
#                                             feature_t...
#                                             learning_rate=None, max_bin=None,
#                                             max_cat_threshold=None,
#                                             max_cat_to_onehot=None,
#                                             max_delta_step=None, max_depth=None,
#                                             max_leaves=None,
#                                             min_child_weight=None, missing=nan,
#                                             monotone_constraints=None,
#                                             multi_strategy=None,
#                                             n_estimators=None, n_jobs=None,
#                                             num_parallel_tree=None, ...))],
#                   final_estimator=MLPRegressor(hidden_layer_sizes=(400, 200,
#                                                                    100, 50),
#                                                random_state=42))

# %% [markdown]
# ## implementing kfold

# %%
## For Risk Predicion
from sklearn.model_selection import KFold
from sklearn.metrics import r2_score

kf = KFold(n_splits=5, shuffle=True, random_state=42)

predictions = np.zeros(len(X))

for train_index, test_index in kf.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    model.fit(X_train, y_train)
    fold_preds = model.predict(X_test)
    fold_r2 = r2_score(y_test, fold_preds)
    print(f"R2 Score for this fold: {fold_r2}")

    predictions[test_index] += fold_preds

final_r2 = r2_score(y, predictions)
print(f"\nOverall R2 Score: {final_r2}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 13
#      10 X_train, X_test = X.iloc[train_index], X.iloc[test_index]
#      11 y_train, y_test = y.iloc[train_index], y.iloc[test_index]
# ---> 13 model.fit(X_train, y_train)
#      14 fold_preds = model.predict(X_test)
#      15 fold_r2 = r2_score(y_test, fold_preds)
#
# File ~/Documents/BLINC/FABRIC-master/venv/lib/python3.13/site-packages/sklearn/ensemble/_stacking.py:1043, in StackingRegressor.fit(self, X, y, **fit_params)
#    1039 _raise_for_params(fit_params, self, "fit", allow=["sample_weight"])
#    1041 y = column_or_1d(y, warn=True)
# -> 1043 return super().fit(X, y, **fit_params)
#
# File ~/Documents/BLINC/FABRIC-master/venv/lib/python3.13/site-packages/sklearn/base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File ~/Documents/BLINC/FABRIC-master/venv/lib/python3.13/site-packages/sklearn/ensemble/_stacking.py:211, in _BaseStacking.fit(self, X, y, **fit_params)
#     206             self.estimators_.append(estimator)
#     207 else:
#     208     # Fit the base estimators on the whole training data. Those
#     209     # base estimators will be used in transform, predict, and
#     210     # predict_proba. They are exposed publicly.
# --> 211     self.estimators_ = Parallel(n_jobs=self.n_jobs)(
#     212         delayed(_fit_single_estimator)(
#     213             clone(est), X, y, routed_params[name]["fit"]
#     214         )
#     215         for name, est in zip(names, all_estimators)
#     216         if est != "drop"
#     217     )
#     219 self.named_estimators_ = Bunch()
#     220 est_fitted_idx = 0
#
# File ~/Documents/BLINC/FABRIC-master/venv/lib/python3.13/site-packages/sklearn/utils/parallel.py:82, in Parallel.__call__(self, iterable)
#      73 warning_filters = warnings.filters
#      74 iterable_with_config_and_warning_filters = (
#      75     (
#      76         _with_config_and_warning_filters(delayed_func, config, warning_filters),
#    (...)     80     for delayed_func, args, kwargs in iterable
#      81 )
# ---> 82 return super().__call__(iterable_with_config_and_warning_filters)
#
# File ~/Documents/BLINC/FABRIC-master/venv/lib/python3.13/site-packages/joblib/parallel.py:1986, in Parallel.__call__(self, iterable)
#    1984     output = self._get_sequential_output(iterable)
#    1985     next(output)
# -> 1986     return output if self.return_generator else list(output)
#    1988 # Let's create an ID that uniquely identifies the current call. If the
#    1989 # call is interrupted early and that the same instance is immediately
#    1990 # reused, this id will be used to prevent workers that were
#    1991 # concurrently finalizing a task from the previous call to run the
#    1992 # callback.
#    1993 with self._lock:
#
# File ~/Documents/BLINC/FABRIC-master/venv/lib/python3.13/site-packages/joblib/parallel.py:1914, in Parallel._get_sequential_output(self, iterable)
#    1912 self.n_dispatched_batches += 1
#    1913 self.n_dispatched_tasks += 1
# -> 1914 res = func(*args, **kwargs)
#    1915 self.n_completed_tasks += 1
#    1916 self.print_progress()
#
# File ~/Documents/BLINC/FABRIC-master/venv/lib/python3.13/site-packages/sklearn/utils/parallel.py:147, in _FuncWrapper.__call__(self, *args, **kwargs)
#     145 with config_context(**config), warnings.catch_warnings():
#     146     warnings.filters = warning_filters
# --> 147     return self.function(*args, **kwargs)
#
# File ~/Documents/BLINC/FABRIC-master/venv/lib/python3.13/site-packages/sklearn/ensemble/_base.py:39, in _fit_single_estimator(estimator, X, y, fit_params, message_clsname, message)
#      37 else:
#      38     with _print_elapsed_time(message_clsname, message):
# ---> 39         estimator.fit(X, y, **fit_params)
#      40 return estimator
#
# File ~/Documents/BLINC/FABRIC-master/venv/lib/python3.13/site-packages/lightgbm/sklearn.py:1398, in LGBMRegressor.fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_init_score, eval_metric, feature_name, categorical_feature, callbacks, init_model)
#    1381 def fit(  # type: ignore[override]
#    1382     self,
#    1383     X: _LGBM_ScikitMatrixLike,
#    (...)   1395     init_model: Optional[Union[str, Path, Booster, LGBMModel]] = None,
#    1396 ) -> "LGBMRegressor":
#    1397     """Docstring is inherited from the LGBMModel."""
# -> 1398     super().fit(
#    1399         X,
#    1400         y,
#    1401         sample_weight=sample_weight,
#    1402         init_score=init_score,
#    1403         eval_set=eval_set,
#    1404         eval_names=eval_names,
#    1405         eval_sample_weight=eval_sample_weight,
#    1406         eval_init_score=eval_init_score,
#    1407         eval_metric=eval_metric,
#    1408         feature_name=feature_name,
#    1409         categorical_feature=categorical_feature,
#    1410         callbacks=callbacks,
#    1411         init_model=init_model,
#    1412     )
#    1413     return self
#
# File ~/Documents/BLINC/FABRIC-master/venv/lib/python3.13/site-packages/lightgbm/sklearn.py:1049, in LGBMModel.fit(self, X, y, sample_weight, init_score, group, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_group, eval_metric, feature_name, categorical_feature, callbacks, init_model)
#    1046 evals_result: _EvalResultDict = {}
#    1047 callbacks.append(record_evaluation(evals_result))
# -> 1049 self._Booster = train(
#    1050     params=params,
#    1051     train_set=train_set,
#    1052     num_boost_round=self.n_estimators,
#    1053     valid_sets=valid_sets,
#    1054     valid_names=eval_names,
#    1055     feval=eval_metrics_callable,  # type: ignore[arg-type]
#    1056     init_model=init_model,
#    1057     callbacks=callbacks,
#    1058 )
#    1060 # This populates the property self.n_features_, the number of features in the fitted model,
#    1061 # and so should only be set after fitting.
#    1062 #
#    1063 # The related property self._n_features_in, which populates self.n_features_in_,
#    1064 # is set BEFORE fitting.
#    1065 self._n_features = self._Booster.num_feature()
#
# File ~/Documents/BLINC/FABRIC-master/venv/lib/python3.13/site-packages/lightgbm/engine.py:297, in train(params, train_set, num_boost_round, valid_sets, valid_names, feval, init_model, keep_training_booster, callbacks)
#     295 # construct booster
#     296 try:
# --> 297     booster = Booster(params=params, train_set=train_set)
#     298     if is_valid_contain_train:
#     299         booster.set_train_data_name(train_data_name)
#
# File ~/Documents/BLINC/FABRIC-master/venv/lib/python3.13/site-packages/lightgbm/basic.py:3656, in Booster.__init__(self, params, train_set, model_file, model_str)
#    3649     self.set_network(
#    3650         machines=machines,
#    3651         local_listen_port=params["local_listen_port"],
#    3652         listen_time_out=params.get("time_out", 120),
#    3653         num_machines=params["num_machines"],
#    3654     )
#    3655 # construct booster object
# -> 3656 train_set.construct()
#    3657 # copy the parameters from train_set
#    3658 params.update(train_set.get_params())
#
# File ~/Documents/BLINC/FABRIC-master/venv/lib/python3.13/site-packages/lightgbm/basic.py:2590, in Dataset.construct(self)
#    2585             self._set_init_score_by_predictor(
#    2586                 predictor=self._predictor, data=self.data, used_indices=used_indices
#    2587             )
#    2588 else:
#    2589     # create train
# -> 2590     self._lazy_init(
#    2591         data=self.data,
#    2592         label=self.label,
#    2593         reference=None,
#    2594         weight=self.weight,
#    2595         group=self.group,
#    2596         init_score=self.init_score,
#    2597         predictor=self._predictor,
#    2598         feature_name=self.feature_name,
#    2599         categorical_feature=self.categorical_feature,
#    2600         params=self.params,
#    2601         position=self.position,
#    2602     )
#    2603 if self.free_raw_data:
#    2604     self.data = None
#
# File ~/Documents/BLINC/FABRIC-master/venv/lib/python3.13/site-packages/lightgbm/basic.py:2123, in Dataset._lazy_init(self, data, label, reference, weight, group, init_score, predictor, feature_name, categorical_feature, params, position)
#    2121     categorical_feature = reference.categorical_feature
#    2122 if isinstance(data, pd_DataFrame):
# -> 2123     data, feature_name, categorical_feature, self.pandas_categorical = _data_from_pandas(
#    2124         data=data,
#    2125         feature_name=feature_name,
#    2126         categorical_feature=categorical_feature,
#    2127         pandas_categorical=self.pandas_categorical,
#    2128     )
#    2129 elif _is_pyarrow_table(data) and feature_name == "auto":
#    2130     feature_name = data.column_names
#
# File ~/Documents/BLINC/FABRIC-master/venv/lib/python3.13/site-packages/lightgbm/basic.py:868, in _data_from_pandas(data, feature_name, categorical_feature, pandas_categorical)
#     864 df_dtypes.append(np.float32)
#     865 target_dtype = np.result_type(*df_dtypes)
#     867 return (
# --> 868     _pandas_to_numpy(data, target_dtype=target_dtype),
#     869     feature_name,
#     870     categorical_feature,
#     871     pandas_categorical,
#     872 )
#
# File ~/Documents/BLINC/FABRIC-master/venv/lib/python3.13/site-packages/lightgbm/basic.py:814, in _pandas_to_numpy(data, target_dtype)
#     810 def _pandas_to_numpy(
#     811     data: pd_DataFrame,
#     812     target_dtype: "np.typing.DTypeLike",
#     813 ) -> np.ndarray:
# --> 814     _check_for_bad_pandas_dtypes(data.dtypes)
#     815     try:
#     816         # most common case (no nullable dtypes)
#     817         return data.to_numpy(dtype=target_dtype, copy=False)
#
# File ~/Documents/BLINC/FABRIC-master/venv/lib/python3.13/site-packages/lightgbm/basic.py:805, in _check_for_bad_pandas_dtypes(pandas_dtypes_series)
#     799 bad_pandas_dtypes = [
#     800     f"{column_name}: {pandas_dtype}"
#     801     for column_name, pandas_dtype in pandas_dtypes_series.items()
#     802     if not _is_allowed_numpy_dtype(pandas_dtype.type)
#     803 ]
#     804 if bad_pandas_dtypes:
# --> 805     raise ValueError(
#     806         f"pandas dtypes must be int, float or bool.\nFields with bad pandas dtypes: {', '.join(bad_pandas_dtypes)}"
#     807     )
#
# ValueError: pandas dtypes must be int, float or bool.
# Fields with bad pandas dtypes: EventType: object, Severity: object

# %%
X
# Out:
#      SourceClass  DestinationClass  User  Device  EventType  Severity
# 0              1                 1     1       1        0.2       0.1
# 1              1                 1     4       3        0.8       0.9
# 2              0                 1     3       2        0.9       0.1
# 3              0                 1     1       1        0.9       0.4
# 4              0                 1     2       2        0.5       0.4
# ..           ...               ...   ...     ...        ...       ...
# 495            0                 0     4       2        0.1       0.1
# 496            1                 1     4       2        0.8       0.4
# 497            1                 1     4       1        0.8       0.9
# 498            1                 1     2       2        0.6       0.7
# 499            1                 1     3       1        0.3       0.9
#
# [500 rows x 6 columns]

# %%
y
# Out:
# 0      0.13
# 1      0.33
# 2      0.63
# 3      0.63
# 4      0.50
#        ...
# 495    0.63
# 496    0.33
# 497    0.33
# 498    0.27
# 499    0.17
# Name: MLRiskScore, Length: 500, dtype: float64

# %%
y2
# Out:
# 0      0
# 1      0
# 2      1
# 3      1
# 4      1
#       ..
# 495    1
# 496    1
# 497    1
# 498    1
# 499    1
# Name: Access, Length: 500, dtype: int64

# %%
dataset
new_dataset = dataset.iloc[:,:-1]
new_dataset
# Out:
#      SourceClass  DestinationClass  User  Device  EventType  Severity  \
# 0              1                 1     1       1        0.2       0.1
# 1              1                 1     4       3        0.8       0.9
# 2              0                 1     3       2        0.9       0.1
# 3              0                 1     1       1        0.9       0.4
# 4              0                 1     2       2        0.5       0.4
# ..           ...               ...   ...     ...        ...       ...
# 495            0                 0     4       2        0.1       0.1
# 496            1                 1     4       2        0.8       0.4
# 497            1                 1     4       1        0.8       0.9
# 498            1                 1     2       2        0.6       0.7
# 499            1                 1     3       1        0.3       0.9
#
#      MLRiskScore
# 0           0.13
# 1           0.33
# 2           0.63
# 3           0.63
# 4           0.50
# ..           ...
# 495         0.63
# 496         0.33
# 497         0.33
# 498         0.27
# 499         0.17
#
# [500 rows x 7 columns]

# %%
## Predicting Access Revoked or Not
from sklearn.model_selection import KFold
from catboost import CatBoostClassifier
from sklearn.metrics import r2_score

kf = KFold(n_splits=5, shuffle=True, random_state=42)
catboost_model = CatBoostClassifier(iterations=1000, depth=5, learning_rate=0.1, loss_function='Logloss', random_seed=42, verbose = False)

from sklearn.model_selection import KFold
from sklearn.metrics import r2_score

kf = KFold(n_splits=5, shuffle=True, random_state=42)

predictions = np.zeros(len(X))

for train_index, test_index in kf.split(X):
    X_train, X_test = new_dataset.iloc[train_index], new_dataset.iloc[test_index]
    y_train, y_test = y2.iloc[train_index], y2.iloc[test_index]

    catboost_model.fit(X_train, y_train)
    fold_preds = catboost_model.predict(X_test)
    fold_r2 = r2_score(y_test, fold_preds)
#     print(f"R2 Score for this fold: {fold_r2}")

    predictions[test_index] += fold_preds

final_r2 = r2_score(y, predictions)
# print(f"\nOverall R2 Score: {final_r2}")
